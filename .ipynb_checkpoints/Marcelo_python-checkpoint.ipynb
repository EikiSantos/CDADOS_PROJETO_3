# %% [markdown]
# ## Fazendo os import necessários

# %%
# %matplotlib inline
import math
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np

# %%
steam=pd.read_csv("steam-store-games/steam.csv")
steam_description = pd.read_csv("steam-store-games/steam_description_data.csv")
steam_media_data = pd.read_csv("steam-store-games/steam_media_data.csv") #Provavelmente não vamos usar
steam_requirements = pd.read_csv("steam-store-games/steam_requirements_data.csv")
steam_support = pd.read_csv("steam-store-games/steam_support_info.csv")
steam_tag = pd.read_csv("steam-store-games/steamspy_tag_data.csv")

# %%
#jogos_mais_negativos = steam[steam["positive_ratings"]< steam["negative_ratings"]]
#jogos_mais_negativos["owners"].value_counts(True)
#steam= steam.loc[steam["median_playtime"]>0]
n_cat = []
for i in steam.categories:
    n_cat.append(i.count(";")+1)
steam["n_cat"] = pd.Series(n_cat)

# %%
steam.head(50)
# Out:
#     appid                                  name release_date  english  \
# 0      10                        Counter-Strike   2000-11-01        1
# 1      20                 Team Fortress Classic   1999-04-01        1
# 2      30                         Day of Defeat   2003-05-01        1
# 3      40                    Deathmatch Classic   2001-06-01        1
# 4      50             Half-Life: Opposing Force   1999-11-01        1
# 5      60                              Ricochet   2000-11-01        1
# 6      70                             Half-Life   1998-11-08        1
# 7      80        Counter-Strike: Condition Zero   2004-03-01        1
# 8     130                 Half-Life: Blue Shift   2001-06-01        1
# 9     220                           Half-Life 2   2004-11-16        1
# 10    240                Counter-Strike: Source   2004-11-01        1
# 11    280                     Half-Life: Source   2004-06-01        1
# 12    300                 Day of Defeat: Source   2010-07-12        1
# 13    320               Half-Life 2: Deathmatch   2004-11-01        1
# 14    340               Half-Life 2: Lost Coast   2005-10-27        1
# 15    360          Half-Life Deathmatch: Source   2006-05-01        1
# 16    380              Half-Life 2: Episode One   2006-06-01        1
# 17    400                                Portal   2007-10-10        1
# 18    420              Half-Life 2: Episode Two   2007-10-10        1
# 19    440                       Team Fortress 2   2007-10-10        1
# 20    500                           Left 4 Dead   2008-11-17        1
# 21    550                         Left 4 Dead 2   2009-11-19        1
# 22    570                                Dota 2   2013-07-09        1
# 23    620                              Portal 2   2011-04-18        1
# 24    630                           Alien Swarm   2010-07-19        1
# 25    730      Counter-Strike: Global Offensive   2012-08-21        1
# 27   1200         Red Orchestra: Ostfront 41-45   2006-03-14        1
# 28   1250                         Killing Floor   2009-05-14        1
# 30   1500                              Darwinia   2005-07-14        1
# 31   1510                                Uplink   2006-08-23        1
# 32   1520                                DEFCON   2006-09-29        1
# 33   1530                            Multiwinia   2008-09-19        1
# 37   1640        Disciples II: Gallean's Return   2006-07-06        1
# 39   1690                       Space Empires V   2006-10-16        1
# 40   1700                           Arx Fatalis   2007-04-03        1
# 41   1840                      Source Filmmaker   2012-07-10        1
# 42   1900                            Earth 2160   2006-04-01        1
# 43   1930               Two Worlds Epic Edition   2009-04-30        1
# 44   2100         Dark Messiah of Might & Magic   2006-10-25        1
# 45   2200                       Quake III Arena   2007-08-03        1
# 46   2210                              Quake IV   2011-08-04        1
# 47   2270                        Wolfenstein 3D   2007-08-03        1
# 48   2280                         Ultimate Doom   2007-08-03        1
# 49   2290                            Final DOOM   2007-08-03        1
# 50   2300                               DOOM II   2007-08-03        1
# 51   2310                                 QUAKE   2007-08-03        1
# 52   2320                              QUAKE II   2007-08-03        1
# 53   2330  QUAKE II Mission Pack: The Reckoning   2007-08-03        1
# 54   2340    QUAKE II Mission Pack: Ground Zero   2007-08-03        1
# 56   2360                 HeXen: Beyond Heretic   2007-08-03        1
#
#                           developer                publisher  \
# 0                             Valve                    Valve
# 1                             Valve                    Valve
# 2                             Valve                    Valve
# 3                             Valve                    Valve
# 4                  Gearbox Software                    Valve
# 5                             Valve                    Valve
# 6                             Valve                    Valve
# 7                             Valve                    Valve
# 8                  Gearbox Software                    Valve
# 9                             Valve                    Valve
# 10                            Valve                    Valve
# 11                            Valve                    Valve
# 12                            Valve                    Valve
# 13                            Valve                    Valve
# 14                            Valve                    Valve
# 15                            Valve                    Valve
# 16                            Valve                    Valve
# 17                            Valve                    Valve
# 18                            Valve                    Valve
# 19                            Valve                    Valve
# 20                            Valve                    Valve
# 21                            Valve                    Valve
# 22                            Valve                    Valve
# 23                            Valve                    Valve
# 24                            Valve                    Valve
# 25  Valve;Hidden Path Entertainment                    Valve
# 27             Tripwire Interactive     Tripwire Interactive
# 28             Tripwire Interactive     Tripwire Interactive
# 30            Introversion Software    Introversion Software
# 31            Introversion Software    Introversion Software
# 32            Introversion Software    Introversion Software
# 33            Introversion Software    Introversion Software
# 37                   Strategy First           Strategy First
# 39            Malfador Machinations           Strategy First
# 40                   Arkane Studios           Arkane Studios
# 41                            Valve                    Valve
# 42             Reality Pump Studios  Topware Interactive;ACE
# 43             Reality Pump Studios      Topware Interactive
# 44                   Arkane Studios                  Ubisoft
# 45                      id Software              id Software
# 46          RavenSoft / id Software       Bethesda Softworks
# 47                      id Software       Bethesda-Softworks
# 48                      id Software              id Software
# 49                      id Software              id Software
# 50                      id Software              id Software
# 51                      id Software              id Software
# 52                      id Software              id Software
# 53             Xatrix Entertainment              id Software
# 54              Rogue Entertainment              id Software
# 56                   Raven Software              id Software
#
#             platforms  required_age  \
# 0   windows;mac;linux             0
# 1   windows;mac;linux             0
# 2   windows;mac;linux             0
# 3   windows;mac;linux             0
# 4   windows;mac;linux             0
# 5   windows;mac;linux             0
# 6   windows;mac;linux             0
# 7   windows;mac;linux             0
# 8   windows;mac;linux             0
# 9   windows;mac;linux             0
# 10  windows;mac;linux             0
# 11  windows;mac;linux             0
# 12  windows;mac;linux             0
# 13  windows;mac;linux             0
# 14  windows;mac;linux             0
# 15  windows;mac;linux             0
# 16  windows;mac;linux             0
# 17  windows;mac;linux             0
# 18  windows;mac;linux             0
# 19  windows;mac;linux             0
# 20        windows;mac             0
# 21  windows;mac;linux             0
# 22  windows;mac;linux             0
# 23  windows;mac;linux             0
# 24            windows             0
# 25  windows;mac;linux             0
# 27  windows;mac;linux             0
# 28  windows;mac;linux             0
# 30  windows;mac;linux             0
# 31  windows;mac;linux             0
# 32  windows;mac;linux             0
# 33        windows;mac             0
# 37            windows             0
# 39            windows             0
# 40            windows             0
# 41            windows             0
# 42  windows;mac;linux             0
# 43  windows;mac;linux             0
# 44            windows             0
# 45            windows             0
# 46            windows            18
# 47            windows             0
# 48            windows             0
# 49            windows             0
# 50            windows             0
# 51            windows             0
# 52            windows             0
# 53            windows             0
# 54            windows             0
# 56            windows             0
#
#                                            categories  \
# 0   Multi-player;Online Multi-Player;Local Multi-P...
# 1   Multi-player;Online Multi-Player;Local Multi-P...
# 2               Multi-player;Valve Anti-Cheat enabled
# 3   Multi-player;Online Multi-Player;Local Multi-P...
# 4   Single-player;Multi-player;Valve Anti-Cheat en...
# 5   Multi-player;Online Multi-Player;Valve Anti-Ch...
# 6   Single-player;Multi-player;Online Multi-Player...
# 7   Single-player;Multi-player;Valve Anti-Cheat en...
# 8                                       Single-player
# 9   Single-player;Steam Achievements;Steam Trading...
# 10  Multi-player;Cross-Platform Multiplayer;Steam ...
# 11                                      Single-player
# 12  Multi-player;Cross-Platform Multiplayer;Steam ...
# 13  Multi-player;Valve Anti-Cheat enabled;Includes...
# 14                 Single-player;Commentary available
# 15              Multi-player;Valve Anti-Cheat enabled
# 16  Single-player;Steam Achievements;Captions avai...
# 17  Single-player;Steam Achievements;Captions avai...
# 18  Single-player;Steam Achievements;Captions avai...
# 19  Multi-player;Cross-Platform Multiplayer;Steam ...
# 20  Single-player;Multi-player;Co-op;Steam Achieve...
# 21  Single-player;Multi-player;Co-op;Steam Achieve...
# 22  Multi-player;Co-op;Steam Trading Cards;Steam W...
# 23  Single-player;Co-op;Steam Achievements;Full co...
# 24  Single-player;Multi-player;Co-op;Steam Achieve...
# 25  Multi-player;Steam Achievements;Full controlle...
# 27  Multi-player;Steam Achievements;Valve Anti-Che...
# 28  Single-player;Multi-player;Co-op;Cross-Platfor...
# 30                                      Single-player
# 31                                      Single-player
# 32                         Single-player;Multi-player
# 33      Single-player;Multi-player;Steam Achievements
# 37                   Single-player;Multi-player;Co-op
# 39                         Single-player;Multi-player
# 40                                      Single-player
# 41                                     Steam Workshop
# 42  Single-player;Multi-player;Co-op;Cross-Platfor...
# 43  Single-player;Multi-player;Online Multi-Player...
# 44  Single-player;Multi-player;Valve Anti-Cheat en...
# 45             Single-player;Multi-player;Steam Cloud
# 46             Single-player;Multi-player;Steam Cloud
# 47                          Single-player;Steam Cloud
# 48                          Single-player;Steam Cloud
# 49                          Single-player;Steam Cloud
# 50             Single-player;Multi-player;Steam Cloud
# 51       Single-player;Multi-player;Co-op;Steam Cloud
# 52       Single-player;Multi-player;Co-op;Steam Cloud
# 53             Single-player;Multi-player;Steam Cloud
# 54             Single-player;Multi-player;Steam Cloud
# 56                          Single-player;Steam Cloud
#
#                                    genres  \
# 0                                  Action
# 1                                  Action
# 2                                  Action
# 3                                  Action
# 4                                  Action
# 5                                  Action
# 6                                  Action
# 7                                  Action
# 8                                  Action
# 9                                  Action
# 10                                 Action
# 11                                 Action
# 12                                 Action
# 13                                 Action
# 14                                 Action
# 15                                 Action
# 16                                 Action
# 17                                 Action
# 18                                 Action
# 19                    Action;Free to Play
# 20                                 Action
# 21                                 Action
# 22           Action;Free to Play;Strategy
# 23                       Action;Adventure
# 24                                 Action
# 25                    Action;Free to Play
# 27                                 Action
# 28                                 Action
# 30                         Indie;Strategy
# 31                         Indie;Strategy
# 32                         Indie;Strategy
# 33                                  Indie
# 37                               Strategy
# 39                               Strategy
# 40                                    RPG
# 41  Animation & Modeling;Video Production
# 42                               Strategy
# 43                                    RPG
# 44                             Action;RPG
# 45                                 Action
# 46                                 Action
# 47                                 Action
# 48                                 Action
# 49                                 Action
# 50                                 Action
# 51                                 Action
# 52                                 Action
# 53                                 Action
# 54                                 Action
# 56                                 Action
#
#                                         steamspy_tags  achievements  \
# 0                              Action;FPS;Multiplayer             0
# 1                              Action;FPS;Multiplayer             0
# 2                        FPS;World War II;Multiplayer             0
# 3                              Action;FPS;Multiplayer             0
# 4                                   FPS;Action;Sci-fi             0
# 5                              Action;FPS;Multiplayer             0
# 6                                  FPS;Classic;Action             0
# 7                              Action;FPS;Multiplayer             0
# 8                                   FPS;Action;Sci-fi             0
# 9                                   FPS;Action;Sci-fi            33
# 10                             Action;FPS;Multiplayer           147
# 11                                  FPS;Action;Sci-fi             0
# 12                       FPS;World War II;Multiplayer            54
# 13                             Action;FPS;Multiplayer             0
# 14                            FPS;Action;Singleplayer             0
# 15                             Action;FPS;Multiplayer             0
# 16                                  FPS;Action;Sci-fi            13
# 17                   Puzzle;First-Person;Singleplayer            15
# 18                                  FPS;Action;Sci-fi            22
# 19                       Free to Play;Multiplayer;FPS           520
# 20                                  Zombies;Co-op;FPS            73
# 21                                  Zombies;Co-op;FPS            70
# 22                         Free to Play;MOBA;Strategy             0
# 23                          Puzzle;Co-op;First-Person            51
# 24                          Free to Play;Co-op;Action            66
# 25                            FPS;Multiplayer;Shooter           167
# 27                            World War II;Action;FPS            44
# 28                                  FPS;Zombies;Co-op           285
# 30                                 Strategy;Indie;RTS             0
# 31                             Hacking;Indie;Strategy             0
# 32                         Strategy;Indie;Multiplayer            22
# 33                                 Indie;RTS;Strategy            12
# 37               Turn-Based Strategy;Strategy;Classic             0
# 39                                  Strategy;4X;Space             0
# 40                           RPG;First-Person;Classic             0
# 41  Animation & Modeling;Video Production;Free to ...             0
# 42                                Strategy;RTS;Sci-fi             0
# 43                             RPG;Open World;Fantasy             0
# 44                            RPG;Action;First-Person             0
# 45                                 FPS;Action;Classic             0
# 46                                 FPS;Action;Shooter             0
# 47                                 FPS;Classic;Action             0
# 48                                 Classic;FPS;Action             0
# 49                                 FPS;Action;Classic             0
# 50                                 Classic;FPS;Action             0
# 51                                 FPS;Classic;Action             0
# 52                                 FPS;Action;Classic             0
# 53                                 Action;FPS;Classic             0
# 54                                 Action;FPS;Shooter             0
# 56                                 Action;FPS;Classic             0
#
#     positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 0             124534              3339             17612              317
# 1               3318               633               277               62
# 2               3416               398               187               34
# 3               1273               267               258              184
# 4               5250               288               624              415
# 5               2758               684               175               10
# 6              27755              1100              1300               83
# 7              12120              1439               427               43
# 8               3822               420               361              205
# 9              67902              2419               691              402
# 10             76640              3497              6842              400
# 11              3767              1053               190              214
# 12             10489              1210              1356              134
# 13              6020               787               311               32
# 14              5783              1020                46               29
# 15              1362               473               102               81
# 16              7908               517               281              184
# 17             51801              1080               288              137
# 18             13902               696               354              301
# 19            515879             34036              8495              623
# 20             17951               948               897              278
# 21            251789              8418              1615              566
# 22            863507            142079             23944              801
# 23            138220              1891              1102              520
# 24             17435               941               371               83
# 25           2644404            402313             22494             6502
# 27              1562               223               232              258
# 28             53710              2649              1328              306
# 30               472               158               182              273
# 31              1602               152                65               77
# 32              2057               344                80              119
# 33               368                75               121              224
# 37               490               152                 9               12
# 39               191                85                35               35
# 40               671               106                11               21
# 41             15083              1111               239               77
# 42               498               238               405              414
# 43              2656              1055               484              422
# 44              4386               316               634              700
# 45              1362                66               123              103
# 46               891               171                36               32
# 47              1773                87                69              110
# 48              3705               257               125              179
# 49               573                82               120              114
# 50              2517               182                90               78
# 51              2618               136               167              189
# 52              1369               107               291              349
# 53                65                12                32               32
# 54                54                33                 1                1
# 56               249                26                50               50
#
#                  owners  price  n_cat
# 0     10000000-20000000   7.19    4.0
# 1      5000000-10000000   3.99    4.0
# 2      5000000-10000000   3.99    2.0
# 3      5000000-10000000   3.99    4.0
# 4      5000000-10000000   3.99    3.0
# 5      5000000-10000000   3.99    3.0
# 6      5000000-10000000   7.19    5.0
# 7     10000000-20000000   7.19    3.0
# 8      5000000-10000000   3.99    1.0
# 9     10000000-20000000   7.19    7.0
# 10    10000000-20000000   7.19    7.0
# 11      2000000-5000000   0.00    1.0
# 12     5000000-10000000   7.19    7.0
# 13    10000000-20000000   3.99    3.0
# 14    10000000-20000000   0.00    2.0
# 15     5000000-10000000   0.00    2.0
# 16     5000000-10000000   5.79    8.0
# 17    10000000-20000000   7.19    7.0
# 18     5000000-10000000   5.79    8.0
# 19    20000000-50000000   0.00   12.0
# 20     5000000-10000000   7.19   12.0
# 21    10000000-20000000   7.19   13.0
# 22  100000000-200000000   0.00    7.0
# 23    10000000-20000000   7.19   11.0
# 24      2000000-5000000   0.00    8.0
# 25   50000000-100000000   0.00    8.0
# 27       500000-1000000   3.99   10.0
# 28      2000000-5000000  14.99    1.0
# 30       500000-1000000   7.19    2.0
# 31       500000-1000000   6.99    3.0
# 32       500000-1000000   7.19    3.0
# 33       500000-1000000   7.19    2.0
# 37        100000-200000   4.99    7.0
# 39         50000-100000  10.99    3.0
# 40        100000-200000   2.99    3.0
# 41      1000000-2000000   0.00    2.0
# 42      1000000-2000000   3.99    2.0
# 43      1000000-2000000   6.99    2.0
# 44      1000000-2000000   4.29    3.0
# 45        200000-500000  12.99    4.0
# 46        200000-500000  12.99    4.0
# 47        200000-500000   2.99    3.0
# 48       500000-1000000   3.99    3.0
# 49        200000-500000   3.99    2.0
# 50       500000-1000000   3.99    4.0
# 51        200000-500000   3.99    3.0
# 52        200000-500000   3.99    3.0
# 53        200000-500000   2.49    1.0
# 54        200000-500000   2.49    1.0
# 56        200000-500000   2.99    2.0

# %%
n_price = []

for i in steam.price:
    if i < 10:    
        n_price.append(5)
    elif i < 20:
        n_price.append(15)
    elif i < 30:
        n_price.append(25)
    elif i < 40:
        n_price.append(35)
    elif i < 50:
        n_price.append(45)
    elif i < 60:
        n_price.append(55)
    elif i < 70:
        n_price.append(65)
    elif i < 80:
        n_price.append(75)
    elif i < 90:
        n_price.append(85)
    elif i < 100:
        n_price.append(95)
    elif i < 110:
        n_price.append(105)
    elif i < 120:
        n_price.append(115)
    elif i < 130:
        n_price.append(125)
    elif i < 140:
        n_price.append(135)
    elif i < 150:
        n_price.append(145)
    elif i < 160:
        n_price.append(155)
    else:
        n_price.append(170)
steam["n_price"] = pd.Series(n_price)

# %%
steam["ratings"] = steam["positive_ratings"] - steam["negative_ratings"]
n_ratings = []
#2.242.091
for i in steam["ratings"]:
    if i< 2000:
        n_ratings.append(1000)
    elif i< 4000:
        n_ratings.append(3000)
    elif i< 6000:
        n_ratings.append(5000)
    elif i< 8000:
        n_ratings.append(7000)
    elif i< 10000:
        n_ratings.append(9000)
    elif i< 20000:
        n_ratings.append(15000)
    elif i< 30000:
        n_ratings.append(25000)
    elif i< 40000:
        n_ratings.append(35000)
    elif i< 50000:
        n_ratings.append(45000)
    elif i< 60000:
        n_ratings.append(55000)
    elif i< 70000:
        n_ratings.append(65000)
    elif i< 80000:
        n_ratings.append(75000)
    elif i< 90000:
        n_ratings.append(85000)
    elif i < 100000:
        n_ratings.append(95000)
    elif i < 200000:
        n_ratings.append(150000)
    elif i < 300000:
        n_ratings.append(250000)
    elif i < 400000:
        n_ratings.append(350000)
    elif i < 500000:
        n_ratings.append(450000)
    elif i < 600000:
        n_ratings.append(550000)
    elif i < 700000:
        n_ratings.append(650000)
    elif i < 800000:
        n_ratings.append(750000)
    elif i < 900000:
        n_ratings.append(850000)
    elif i < 1000000:
        n_ratings.append(950000)
    elif i < 1100000:
        n_ratings.append(1050000)
    elif i < 1200000:
        n_ratings.append(1150000)
    elif i < 1300000:
        n_ratings.append(1250000)
    elif i < 1400000:
        n_ratings.append(1350000)
    elif i < 1500000:
        n_ratings.append(1450000)
    elif i < 1600000:
        n_ratings.append(1550000)
    elif i < 1700000:
        n_ratings.append(1650000)
    elif i < 1800000:
        n_ratings.append(1750000)
    elif i < 1900000:
        n_ratings.append(1850000)
    elif i < 2000000:
        n_ratings.append(1950000)
    elif i < 2100000:
        n_ratings.append(2050000)
    elif i < 2200000:
        n_ratings.append(2150000)
    elif i < 2300000:
        n_ratings.append(2250000)
    else:
        n_ratings.append(2400000)
steam["n_ratings"] = pd.Series(n_ratings)

# %%
#jogos_mais_negativos[jogos_mais_negativos["genres"].str.contains("Action")]
steam["n_ratings"].value_counts()
# Out:
# 1000.0       2380
# 3000.0        256
# 15000.0        90
# 5000.0         89
# 7000.0         56
# 9000.0         49
# 25000.0        37
# 45000.0        17
# 35000.0        13
# 150000.0       11
# 55000.0         5
# 75000.0         5
# 65000.0         5
# 250000.0        4
# 95000.0         2
# 85000.0         2
# 2250000.0       1
# 750000.0        1
# 450000.0        1
# Name: n_ratings, dtype: int64

# %%
#steam_cat=steam[steam["genres"].str.contains("Gore")]
#steam.head(500)

# %%
#lista = [0,5,15,40,80,150,1000]
#pd.cut(steam.price, bins=lista).value_counts()

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder()

# %%
X_num1 = steam[["n_price"]]
X_num2 = steam[["n_cat"]]
#X_cat = steam[["genres"]]

# %%
#y_positive = steam['positive_ratings']
#y_negative = steam['negative_ratings']
y_ratings = steam["n_ratings"]

# %%
#X_cat_encoded = encoder.fit_transform(X_cat)

# %%
#encoder.categories_

#X_cat_encoded.toarray()[0]

# %%
X_num_array1 = X_num1.values

X_num_array2 = X_num2.values

X_cat_encoded_array = X_cat_encoded.toarray()

#X = np.concatenate((X_num_array, X_cat_encoded_array), axis=1)
X = np.concatenate((X_num_array1, X_num_array2), axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y_ratings)

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(accuracy_score(y_test, y_pred))
# Out:
# C:\Users\marce\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-429-0813a879189c> in <module>
#       6
#       7 model = RandomForestClassifier()
# ----> 8 model.fit(X_train, y_train)
#       9 y_pred = model.predict(X_test)
#      10
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     251         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_negative)

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(accuracy_score(y_test, y_pred))
